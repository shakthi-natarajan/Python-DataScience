# %% [markdown]
# ## import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Reading csv file
DF1= pd.read_csv('Bike_Share_London.csv')

# %%
DF1
# Out:
#              timestamp  cnt   t1   t2   hum  wind_speed  weather_code  \
# 0     01/01/2016 00:00  786  6.0  3.5  81.0        13.0             1
# 1     01/01/2016 01:00  660  5.5  3.0  84.0        11.0             1
# 2     01/01/2016 02:00  387  5.0  2.5  84.0        10.0             1
# 3     01/01/2016 03:00  294  5.0  4.5  81.0         5.0             1
# 4     01/01/2016 04:00  219  5.0  4.0  76.0         5.5             1
# ...                ...  ...  ...  ...   ...         ...           ...
# 8694  31/12/2016 19:00  493  9.0  6.0  82.0        17.0             4
# 8695  31/12/2016 20:00  465  8.5  6.5  84.5        13.0             4
# 8696  31/12/2016 21:00  474  8.0  6.0  87.0        12.0             4
# 8697  31/12/2016 22:00  587  8.0  6.0  90.0        12.0             4
# 8698  31/12/2016 23:00  697  8.0  5.0  87.0        18.5             4
#
#       is_holiday  is_weekend  season
# 0              1           0       3
# 1              1           0       3
# ...

# %%
# Renaming columns
DF1.columns=['Time Stamp', 'Count', 
             'Temperature', 'F_Temp', 
             'Humidity', 'Wind Speed', 
             'Weather Code', 'is Holiday', 
             'is Weekend', 'Season']

# %%
DF1
# Out:
#             Time Stamp  Count  Temperature  F_Temp  Humidity  Wind Speed  \
# 0     01/01/2016 00:00    786          6.0     3.5      81.0        13.0
# 1     01/01/2016 01:00    660          5.5     3.0      84.0        11.0
# 2     01/01/2016 02:00    387          5.0     2.5      84.0        10.0
# 3     01/01/2016 03:00    294          5.0     4.5      81.0         5.0
# 4     01/01/2016 04:00    219          5.0     4.0      76.0         5.5
# ...                ...    ...          ...     ...       ...         ...
# 8694  31/12/2016 19:00    493          9.0     6.0      82.0        17.0
# 8695  31/12/2016 20:00    465          8.5     6.5      84.5        13.0
# 8696  31/12/2016 21:00    474          8.0     6.0      87.0        12.0
# 8697  31/12/2016 22:00    587          8.0     6.0      90.0        12.0
# 8698  31/12/2016 23:00    697          8.0     5.0      87.0        18.5
#
#       Weather Code  is Holiday  is Weekend  Season
# ...

# %%
#Row count
len(DF1)
# Out:
# 8699

# %%
#count of each col
DF1.count()
# Out:
# Time Stamp      8699
# Count           8699
# Temperature     8699
# F_Temp          8699
# Humidity        8699
# Wind Speed      8699
# Weather Code    8699
# is Holiday      8699
# is Weekend      8699
# Season          8699
# dtype: int64

# %%
#First 24 and last 24 records
DF1.head(24)
# Out:
#           Time Stamp  Count  Temperature  F_Temp  Humidity  Wind Speed  \
# 0   01/01/2016 00:00    786          6.0     3.5      81.0        13.0
# 1   01/01/2016 01:00    660          5.5     3.0      84.0        11.0
# 2   01/01/2016 02:00    387          5.0     2.5      84.0        10.0
# 3   01/01/2016 03:00    294          5.0     4.5      81.0         5.0
# 4   01/01/2016 04:00    219          5.0     4.0      76.0         5.5
# 5   01/01/2016 05:00    153          4.0     3.5      87.0         5.0
# 6   01/01/2016 06:00    120          3.0     0.0      87.0        10.0
# 7   01/01/2016 07:00     96          3.0     0.0      87.0        12.0
# 8   01/01/2016 08:00    117          3.0     0.0      87.0        12.0
# 9   01/01/2016 09:00    165          4.5     1.5      84.0        14.0
# 10  01/01/2016 10:00    358          5.5     2.5      76.0        17.0
# 11  01/01/2016 11:00    595          6.5     3.5      81.0        16.0
# ...

# %%
DF1.tail(24)
# Out:
#             Time Stamp  Count  Temperature  F_Temp  Humidity  Wind Speed  \
# 8675  31/12/2016 00:00    146          5.0     2.5     100.0        10.0
# 8676  31/12/2016 01:00    123          5.0     3.5     100.0         7.5
# 8677  31/12/2016 02:00     85          6.0     4.0      93.0         8.0
# 8678  31/12/2016 03:00     49          6.0     3.5      93.0        12.0
# 8679  31/12/2016 04:00     50          6.5     4.5      93.0        11.0
# 8680  31/12/2016 05:00     48          7.0     5.0      93.0        11.0
# 8681  31/12/2016 06:00     51          7.0     5.0      93.0        11.0
# 8682  31/12/2016 07:00     93          7.0     4.5      90.0        15.0
# 8683  31/12/2016 08:00    211          6.0     2.5      96.5        17.5
# 8684  31/12/2016 09:00    376          6.0     3.0     100.0        14.0
# 8685  31/12/2016 10:00    642          7.0     4.0      93.0        15.0
# 8686  31/12/2016 11:00    824          7.0     4.0      93.0        18.0
# ...

# %%
#Find highest count
DF1['Count'].max()
# Out:
# 5422

# %%
#Group datya set by season
DF1_G=DF1.groupby('Season')

# %%
DF1_G.groups
# Out:
# {0: [1432, 1433, 1434, 1435, 1436, 1437, 1438, 1439, 1440, 1441, 1442, 1443, 1444, 1445, 1446, 1447, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1466, 1467, 1468, 1469, 1470, 1471, 1472, 1473, 1474, 1475, 1476, 1477, 1478, 1479, 1480, 1481, 1482, 1483, 1484, 1485, 1486, 1487, 1488, 1489, 1490, 1491, 1492, 1493, 1494, 1495, 1496, 1497, 1498, 1499, 1500, 1501, 1502, 1503, 1504, 1505, 1506, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1519, 1520, 1521, 1522, 1523, 1524, 1525, 1526, 1527, 1528, 1529, 1530, 1531, ...], 1: [3624, 3625, 3626, 3627, 3628, 3629, 3630, 3631, 3632, 3633, 3634, 3635, 3636, 3637, 3638, 3639, 3640, 3641, 3642, 3643, 3644, 3645, 3646, 3647, 3648, 3649, 3650, 3651, 3652, 3653, 3654, 3655, 3656, 3657, 3658, 3659, 3660, 3661, 3662, 3663, 3664, 3665, 3666, 3667, 3668, 3669, 3670, 3671, 3672, 3673, 3674, 3675, 3676, 3677, 3678, 3679, 3680, 3681, 3682, 3683, 3684, 3685, 3686, 3687,
# ...

# %%
#Average bike share count 
DF1['Count'].mean()
# Out:
# 1164.4494769513738

# %%
#Average bike share count by season
DF1_G['Count'].mean()
# Out:
# Season
# 0    1107.348084
# 1    1480.658280
# 2    1229.922611
# 3     839.768382
# Name: Count, dtype: float64

# %%
#Find the number of bike shares when the weather is hottest 
#hottest
MaxTemp=DF1['Temperature'].max()
BikeShareHD= DF1[DF1['Temperature']== MaxTemp]
BikeShareHD
BikeShareHD['Count'].sum()
# Out:
# 3693

# %%
#Find the number of bike shares when the weather is coldest
MinTemp=DF1['Temperature'].min()
BikeShareCD=DF1[DF1['Temperature']== MinTemp]
BikeShareCD['Count'].sum()
# Out:
# 2830

# %%
#Find the number of bike shares when the wind speed is highest
HighestWS=DF1['Wind Speed'].max()
BikeShareHW=DF1[DF1['Wind Speed']==HighestWS]
BikeShareHW['Count'].sum()
# Out:
# 556

# %%
#Find the lowest number of bike shares in winter
DF1_Group_Season= DF1.groupby('Season')
Group_Winter=DF1_Group_Season.get_group(3)
Group_Winter['Count'].min()
# Out:
# 12

# %%
#another way of finding lowest number of bike share in winter
DF1_Group_Season= DF1.groupby('Season')
DF1_Group_Season.get_group(3)['Count'].min()
# Out:
# 12

# %%
#Find the highest number of bike shares in autumn
Group_Autumn=DF1_Group_Season.get_group(2)
Group_Autumn['Count'].max()
# Out:
# 5422

# %%
#Find the average humidity in spring
Group_Spring=DF1_Group_Season.get_group(0)
Group_Spring['Humidity'].mean()
# Out:
# 69.88207116788321

# %%
#summer
Group_Summer=DF1_Group_Season.get_group(1)

# %%
#Another way of scatter plot
x= DF1['Temperature']
y= DF1['Count']
Figure, Axes= plt.subplots(figsize=(140,60))
Axes.scatter(x,y)
#plt.show()

# %%
#Create a pie chart that showed the distribution of bike shares by season.
Labels=['Spring', 'Summer', 'Fall', 'Winter']
Values=[Group_Spring['Count'].sum(),
    Group_Summer['Count'].sum(), 
    Group_Autumn['Count'].sum(),
    Group_Winter['Count'].sum()]
Figure, Axes= plt.subplots()
Axes.pie(Values, labels=Labels, autopct='%1.1f%%')
plt.show()
